# %%
import pandas as pd
df = pd.read_csv("scraped_it_cases/it_act_dataset.csv")
len(df), df.url.nunique(), df.outcome_label.value_counts()
df.sample(3)[["title","url","outcome_label","outcome_phrase","it_sections","text_length"]]
# Out:
#                                                   title  \
# 3299  Charan Lal Sahu Etc. Etc vs Union Of India And...
# 4229  Progress Rail Locomotive ... vs Deputy Commiss...
# 317   Persistent Systems Ltd vs Pune Iii on 18 Augus...
#
#                                          url     outcome_label  \
# 3299    https://indiankanoon.org/doc/299215/      INCONCLUSIVE
# 4229  https://indiankanoon.org/doc/90919026/      INCONCLUSIVE
# 317   https://indiankanoon.org/doc/46068540/  PETITION_ALLOWED
#
#          outcome_phrase it_sections  text_length
# 3299                NaN     Unknown       383907
# 4229                NaN     Unknown       334890
# 317   appeal is allowed     Unknown        15104

# %%
import pandas as pd
df = pd.read_csv("C:/Legal AI Project/scraped_it_cases/train.csv")
sec_cols = [c for c in df.columns if c.startswith("sec_")]
print(df[sec_cols].sum().sort_values(ascending=False))
# Out:
# sec_67     30
# sec_66A    15
# sec_67B    15
# sec_66     15
# sec_66E    12
# sec_66D     9
# sec_67A     7
# sec_69A     7
# sec_79      7
# sec_66C     4
# sec_43      3
# sec_65      3
# sec_69      3
# sec_66B     2
# sec_68      2
# sec_70      1
# sec_72A     1
# sec_72      0
# sec_73      0
# sec_74      0
# dtype: int64

# %%
ex = df[df["sec_67"]==1][["title","it_sections","operative_snippet"]].head(3)
print(ex.to_string(index=False))
# Out:
#                                                                                                      title it_sections                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        operative_snippet
# ...

# %%
sec_cols = [c for c in df.columns if c.startswith("sec_")]
zero_cols = [c for c in sec_cols if df[c].sum()==0]
# drop zero_cols from training matrix assembly

# %%
import pandas as pd

df = pd.read_csv("C:/Legal AI Project/scraped_it_cases/train.csv")

# Apply the same filter used in ensure_binary()
train_used = df[df["who_won"].isin(["PETITIONER", "RESPONDENT"])]

print("Total rows in train.csv:", len(df))
print("Rows used for training:", len(train_used))
print("\nClass counts:")
print(train_used["who_won"].value_counts())
# Out:
# Total rows in train.csv: 877
# Rows used for training: 877
#
# Class counts:
# who_won
# PETITIONER    708
# RESPONDENT    169
# Name: count, dtype: int64
